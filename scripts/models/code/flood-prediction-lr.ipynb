# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

import matplotlib.pyplot as plt
# Out:
# /kaggle/input/flood-prediction-factors/flood.csv

# %%
df = pd.read_csv("/kaggle/input/flood-prediction-factors/flood.csv")

# %%
df.head()
# Out:
#    MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                 3                   8                6              6
# 1                 8                   4                5              7
# 2                 3                  10                4              1
# 3                 4                   4                2              7
# 4                 3                   7                5              2
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             4              4            6          2                      3
# 1             7              9            1          5                      5
# 2             7              5            4          7                      4
# 3             3              4            1          4                      6
# 4             5              8            5          2                      7
#
#    Encroachments  ...  DrainageSystems  CoastalVulnerability  Landslides  \
# 0              2  ...               10                     7           4
# 1              4  ...                9                     2           6
# 2              9  ...                7                     4           4
# 3              4  ...                4                     2           6
# 4              5  ...                7                     6           5
#
#    Watersheds  DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0           2                            3                4            3
# 1           2                            1                1            9
# 2           8                            6                1            8
# 3           6                            8                8            6
# 4           3                            3                4            4
#
#    InadequatePlanning  PoliticalFactors  FloodProbability
# 0                   2                 6             0.450
# 1                   1                 3             0.475
# 2                   3                 6             0.515
# 3                   6                10             0.520
# 4                   3                 4             0.475
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   MonsoonIntensity                 50000 non-null  int64
#  1   TopographyDrainage               50000 non-null  int64
#  2   RiverManagement                  50000 non-null  int64
#  3   Deforestation                    50000 non-null  int64
#  4   Urbanization                     50000 non-null  int64
#  5   ClimateChange                    50000 non-null  int64
#  6   DamsQuality                      50000 non-null  int64
#  7   Siltation                        50000 non-null  int64
#  8   AgriculturalPractices            50000 non-null  int64
#  9   Encroachments                    50000 non-null  int64
#  10  IneffectiveDisasterPreparedness  50000 non-null  int64
#  11  DrainageSystems                  50000 non-null  int64
#  12  CoastalVulnerability             50000 non-null  int64
#  13  Landslides                       50000 non-null  int64
#  14  Watersheds                       50000 non-null  int64
#  15  DeterioratingInfrastructure      50000 non-null  int64
#  16  PopulationScore                  50000 non-null  int64
#  17  WetlandLoss                      50000 non-null  int64
#  18  InadequatePlanning               50000 non-null  int64
#  19  PoliticalFactors                 50000 non-null  int64
#  20  FloodProbability                 50000 non-null  float64
# dtypes: float64(1), int64(20)
# memory usage: 8.0 MB

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 0 Null Values
# ### 0 Duplicated Values

# %%
df.corr()
# Out:
#                                  MonsoonIntensity  TopographyDrainage  \
# MonsoonIntensity                         1.000000           -0.003470
# TopographyDrainage                      -0.003470            1.000000
# RiverManagement                          0.002247            0.002492
# Deforestation                           -0.005384            0.002046
# Urbanization                             0.005092            0.000116
# ClimateChange                            0.005959           -0.002288
# DamsQuality                              0.002790           -0.004472
# Siltation                               -0.003191            0.010675
# AgriculturalPractices                    0.002723           -0.004550
# Encroachments                           -0.003723           -0.007272
# IneffectiveDisasterPreparedness          0.002358            0.001328
# DrainageSystems                         -0.000118           -0.001608
# CoastalVulnerability                    -0.004600           -0.000717
# Landslides                              -0.002315           -0.002040
# Watersheds                              -0.008859            0.005312
# DeterioratingInfrastructure              0.001763            0.003654
# PopulationScore                         -0.003597            0.005887
# WetlandLoss                              0.005938            0.003515
# InadequatePlanning                       0.003455            0.005276
# PoliticalFactors                         0.005402            0.008191
# FloodProbability                         0.224081            0.229414
#
#                                  RiverManagement  Deforestation  Urbanization  \
# MonsoonIntensity                        0.002247      -0.005384      0.005092
# TopographyDrainage                      0.002492       0.002046      0.000116
# RiverManagement                         1.000000       0.004808     -0.009651
# Deforestation                           0.004808       1.000000     -0.011325
# Urbanization                           -0.009651      -0.011325      1.000000
# ClimateChange                           0.007199       0.000517      0.007478
# DamsQuality                             0.007697      -0.000728      0.000268
# Siltation                              -0.000389      -0.000823     -0.001287
# AgriculturalPractices                   0.003635       0.002929     -0.001391
# Encroachments                           0.009253      -0.003507     -0.011386
# IneffectiveDisasterPreparedness         0.006269       0.002312      0.001289
# DrainageSystems                         0.002171      -0.001060     -0.005281
# CoastalVulnerability                   -0.000111      -0.003019     -0.000881
# Landslides                             -0.004339       0.005258     -0.000651
# Watersheds                              0.000097       0.002171     -0.003479
# DeterioratingInfrastructure             0.000604      -0.002093      0.004222
# PopulationScore                        -0.001382       0.000138      0.002154
# WetlandLoss                             0.002012      -0.000718      0.013263
# InadequatePlanning                      0.000364      -0.001108     -0.000864
# PoliticalFactors                       -0.006323       0.001242     -0.002418
# FloodProbability                        0.228917       0.220237      0.220867
#
#                                  ClimateChange  DamsQuality  Siltation  \
# MonsoonIntensity                      0.005959     0.002790  -0.003191
# TopographyDrainage                   -0.002288    -0.004472   0.010675
# RiverManagement                       0.007199     0.007697  -0.000389
# Deforestation                         0.000517    -0.000728  -0.000823
# Urbanization                          0.007478     0.000268  -0.001287
# ClimateChange                         1.000000    -0.002889   0.001514
# DamsQuality                          -0.002889     1.000000   0.003239
# Siltation                             0.001514     0.003239   1.000000
# AgriculturalPractices                -0.003362     0.001743  -0.003911
# Encroachments                         0.000075     0.001638   0.000158
# IneffectiveDisasterPreparedness      -0.005455    -0.001116   0.000667
# DrainageSystems                      -0.007587     0.004165  -0.008296
# CoastalVulnerability                 -0.001467    -0.009503  -0.003564
# Landslides                            0.000689     0.000436  -0.001866
# Watersheds                            0.003023     0.005322   0.003682
# DeterioratingInfrastructure           0.003281    -0.004001   0.003045
# PopulationScore                      -0.008334     0.006856  -0.002484
# WetlandLoss                          -0.000547    -0.000662   0.007903
# InadequatePlanning                   -0.000186     0.001535   0.011918
# PoliticalFactors                     -0.004453     0.001699  -0.001597
# FloodProbability                      0.220986     0.227467   0.226544
#
#                                  AgriculturalPractices  Encroachments  ...  \
# MonsoonIntensity                              0.002723      -0.003723  ...
# TopographyDrainage                           -0.004550      -0.007272  ...
# RiverManagement                               0.003635       0.009253  ...
# Deforestation                                 0.002929      -0.003507  ...
# Urbanization                                 -0.001391      -0.011386  ...
# ClimateChange                                -0.003362       0.000075  ...
# DamsQuality                                   0.001743       0.001638  ...
# Siltation                                    -0.003911       0.000158  ...
# AgriculturalPractices                         1.000000      -0.006564  ...
# Encroachments                                -0.006564       1.000000  ...
# IneffectiveDisasterPreparedness               0.003387       0.001461  ...
# DrainageSystems                               0.000648      -0.005960  ...
# CoastalVulnerability                         -0.003708      -0.006591  ...
# Landslides                                    0.004142      -0.003032  ...
# Watersheds                                    0.004371       0.003679  ...
# DeterioratingInfrastructure                   0.003248       0.002774  ...
# PopulationScore                               0.001678       0.003874  ...
# WetlandLoss                                  -0.007963       0.005706  ...
# InadequatePlanning                           -0.002221       0.001380  ...
# PoliticalFactors                             -0.001280      -0.007547  ...
# FloodProbability                              0.221846       0.218259  ...
#
#                                  DrainageSystems  CoastalVulnerability  \
# MonsoonIntensity                       -0.000118             -0.004600
# TopographyDrainage                     -0.001608             -0.000717
# RiverManagement                         0.002171             -0.000111
# Deforestation                          -0.001060             -0.003019
# Urbanization                           -0.005281             -0.000881
# ClimateChange                          -0.007587             -0.001467
# DamsQuality                             0.004165             -0.009503
# Siltation                              -0.008296             -0.003564
# AgriculturalPractices                   0.000648             -0.003708
# Encroachments                          -0.005960             -0.006591
# IneffectiveDisasterPreparedness         0.003551              0.001399
# DrainageSystems                         1.000000              0.008439
# CoastalVulnerability                    0.008439              1.000000
# Landslides                              0.003746              0.003260
# Watersheds                             -0.002762              0.002213
# DeterioratingInfrastructure            -0.002501             -0.004779
# PopulationScore                        -0.000285              0.001622
# WetlandLoss                            -0.006217             -0.007103
# InadequatePlanning                     -0.008116             -0.009539
# PoliticalFactors                        0.001197             -0.003269
# FloodProbability                        0.217895              0.215187
#
#                                  Landslides  Watersheds  \
# MonsoonIntensity                  -0.002315   -0.008859
# TopographyDrainage                -0.002040    0.005312
# RiverManagement                   -0.004339    0.000097
# Deforestation                      0.005258    0.002171
# Urbanization                      -0.000651   -0.003479
# ClimateChange                      0.000689    0.003023
# DamsQuality                        0.000436    0.005322
# Siltation                         -0.001866    0.003682
# AgriculturalPractices              0.004142    0.004371
# Encroachments                     -0.003032    0.003679
# IneffectiveDisasterPreparedness   -0.001763   -0.000245
# DrainageSystems                    0.003746   -0.002762
# CoastalVulnerability               0.003260    0.002213
# Landslides                         1.000000    0.003552
# Watersheds                         0.003552    1.000000
# DeterioratingInfrastructure        0.002840    0.004844
# PopulationScore                    0.001621    0.001352
# WetlandLoss                       -0.002325   -0.007696
# InadequatePlanning                -0.009414    0.009347
# PoliticalFactors                   0.003839   -0.003130
# FloodProbability                   0.222991    0.228152
#
#                                  DeterioratingInfrastructure  PopulationScore  \
# MonsoonIntensity                                    0.001763        -0.003597
# TopographyDrainage                                  0.003654         0.005887
# RiverManagement                                     0.000604        -0.001382
# Deforestation                                      -0.002093         0.000138
# Urbanization                                        0.004222         0.002154
# ClimateChange                                       0.003281        -0.008334
# DamsQuality                                        -0.004001         0.006856
# Siltation                                           0.003045        -0.002484
# AgriculturalPractices                               0.003248         0.001678
# Encroachments                                       0.002774         0.003874
# IneffectiveDisasterPreparedness                     0.000149        -0.004047
# DrainageSystems                                    -0.002501        -0.000285
# CoastalVulnerability                               -0.004779         0.001622
# Landslides                                          0.002840         0.001621
# Watersheds                                          0.004844         0.001352
# DeterioratingInfrastructure                         1.000000         0.000541
# PopulationScore                                     0.000541         1.000000
# WetlandLoss                                        -0.000104         0.003615
# InadequatePlanning                                  0.007258        -0.002177
# PoliticalFactors                                    0.004304         0.007371
# FloodProbability                                    0.229444         0.226928
#
#                                  WetlandLoss  InadequatePlanning  \
# MonsoonIntensity                    0.005938            0.003455
# TopographyDrainage                  0.003515            0.005276
# RiverManagement                     0.002012            0.000364
# Deforestation                      -0.000718           -0.001108
# Urbanization                        0.013263           -0.000864
# ClimateChange                      -0.000547           -0.000186
# DamsQuality                        -0.000662            0.001535
# Siltation                           0.007903            0.011918
# AgriculturalPractices              -0.007963           -0.002221
# Encroachments                       0.005706            0.001380
# IneffectiveDisasterPreparedness    -0.004337            0.003628
# DrainageSystems                    -0.006217           -0.008116
# CoastalVulnerability               -0.007103           -0.009539
# Landslides                         -0.002325           -0.009414
# Watersheds                         -0.007696            0.009347
# DeterioratingInfrastructure        -0.000104            0.007258
# PopulationScore                     0.003615           -0.002177
# WetlandLoss                         1.000000           -0.003828
# InadequatePlanning                 -0.003828            1.000000
# PoliticalFactors                    0.002627           -0.004491
# FloodProbability                    0.223732            0.223329
#
#                                  PoliticalFactors  FloodProbability
# MonsoonIntensity                         0.005402          0.224081
# TopographyDrainage                       0.008191          0.229414
# RiverManagement                         -0.006323          0.228917
# Deforestation                            0.001242          0.220237
# Urbanization                            -0.002418          0.220867
# ClimateChange                           -0.004453          0.220986
# DamsQuality                              0.001699          0.227467
# Siltation                               -0.001597          0.226544
# AgriculturalPractices                   -0.001280          0.221846
# Encroachments                           -0.007547          0.218259
# IneffectiveDisasterPreparedness          0.001102          0.225126
# DrainageSystems                          0.001197          0.217895
# CoastalVulnerability                    -0.003269          0.215187
# Landslides                               0.003839          0.222991
# Watersheds                              -0.003130          0.228152
# DeterioratingInfrastructure              0.004304          0.229444
# PopulationScore                          0.007371          0.226928
# WetlandLoss                              0.002627          0.223732
# InadequatePlanning                      -0.004491          0.223329
# PoliticalFactors                         1.000000          0.225009
# FloodProbability                         0.225009          1.000000
#
# [21 rows x 21 columns]

# %%
 df.corr()['FloodProbability']
# Out:
# MonsoonIntensity                   0.224081
# TopographyDrainage                 0.229414
# RiverManagement                    0.228917
# Deforestation                      0.220237
# Urbanization                       0.220867
# ClimateChange                      0.220986
# DamsQuality                        0.227467
# Siltation                          0.226544
# AgriculturalPractices              0.221846
# Encroachments                      0.218259
# IneffectiveDisasterPreparedness    0.225126
# DrainageSystems                    0.217895
# CoastalVulnerability               0.215187
# Landslides                         0.222991
# Watersheds                         0.228152
# DeterioratingInfrastructure        0.229444
# PopulationScore                    0.226928
# WetlandLoss                        0.223732
# InadequatePlanning                 0.223329
# PoliticalFactors                   0.225009
# FloodProbability                   1.000000
# Name: FloodProbability, dtype: float64

# %% [markdown]
# #### Correlation between Target and other features is similar.
# #### Thus, every column is important.

# %% [markdown]
# ### **Converting target feature (which is probability based, eg - 0.3, 0.2,0.7) to discrete values (binary => 0,1)**

# %%
df['FloodProbability'] = (df['FloodProbability'] >= 0.5).astype(int)

# %%
df.head()
# Out:
#    MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                 3                   8                6              6
# 1                 8                   4                5              7
# 2                 3                  10                4              1
# 3                 4                   4                2              7
# 4                 3                   7                5              2
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             4              4            6          2                      3
# 1             7              9            1          5                      5
# 2             7              5            4          7                      4
# 3             3              4            1          4                      6
# 4             5              8            5          2                      7
#
#    Encroachments  ...  DrainageSystems  CoastalVulnerability  Landslides  \
# 0              2  ...               10                     7           4
# 1              4  ...                9                     2           6
# 2              9  ...                7                     4           4
# 3              4  ...                4                     2           6
# 4              5  ...                7                     6           5
#
#    Watersheds  DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0           2                            3                4            3
# 1           2                            1                1            9
# 2           8                            6                1            8
# 3           6                            8                8            6
# 4           3                            3                4            4
#
#    InadequatePlanning  PoliticalFactors  FloodProbability
# 0                   2                 6                 0
# 1                   1                 3                 0
# 2                   3                 6                 1
# 3                   6                10                 1
# 4                   3                 4                 0
#
# [5 rows x 21 columns]

# %%
class_counts = df['FloodProbability'].value_counts()

class_percentages = (class_counts / len(df)) * 100

print(f"Class counts: {class_counts}")
print()
print(f"Class percentages: {class_percentages}")
# Out:
# Class counts: FloodProbability
# 1    25513
# 0    24487
# Name: count, dtype: int64
#
# Class percentages: FloodProbability
# 1    51.026
# 0    48.974
# Name: count, dtype: float64

# %%
plt.figure(figsize=(6, 4))  # Adjust the figure size if needed
df['FloodProbability'].value_counts().plot(kind='bar', color=['skyblue', 'orange'])
plt.title('Distribution of Target Variable')
plt.xlabel('Target Value')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #### **We have a balanced dataset**

# %% [markdown]
# ## **ANN**

# %% [markdown]
# #### Train-Test Split (70% Train - 30% Test)

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns=['FloodProbability'])
y = df['FloodProbability']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train.head(3)
# Out:
#        MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 38094                 5                   6                1              8
# 40624                 2                   3                6              8
# 49425                 9                   7                5              3
#
#        Urbanization  ClimateChange  DamsQuality  Siltation  \
# 38094             3              8            5          6
# 40624             6              4            3          9
# 49425             9              7            9          4
#
#        AgriculturalPractices  Encroachments  IneffectiveDisasterPreparedness  \
# 38094                      3              3                                3
# 40624                      9              5                                6
# 49425                      7              4                                8
#
#        DrainageSystems  CoastalVulnerability  Landslides  Watersheds  \
# 38094                4                     7           3           5
# 40624                5                     9           4           3
# 49425                4                     4           3           3
#
#        DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 38094                            5                9            1
# 40624                            5                6            3
# 49425                            5                8            7
#
#        InadequatePlanning  PoliticalFactors
# 38094                   3                11
# 40624                   6                 2
# 49425                   5                 4

# %%
y_train.head(3)
# Out:
# 38094    0
# 40624    1
# 49425    1
# Name: FloodProbability, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_s = scaler.fit_transform(X_train)
X_test_s = scaler.transform(X_test)

# %% [markdown]
# #### **Building ANN**

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
num_features = len(X_train.columns)
print(f"Number of input features: {num_features}")
# Out:
# Number of input features: 20

# %%
model = Sequential()

model.add(Dense(1,activation='sigmoid',input_dim=20))
"""
model.add(Dropout(0.2))

model.add(Dense(16,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(10,activation='relu'))
model.add(Dropout(0.1))

model.add(Dense(5,activation='relu'))

model.add(Dense(3,activation='relu'))

model.add(Dense(1,activation='sigmoid'))
"""
# Out:
# "\nmodel.add(Dropout(0.2))\n\nmodel.add(Dense(16,activation='relu'))\nmodel.add(Dropout(0.2))\n\nmodel.add(Dense(10,activation='relu'))\nmodel.add(Dropout(0.1))\n\nmodel.add(Dense(5,activation='relu'))\n\nmodel.add(Dense(3,activation='relu'))\n\nmodel.add(Dense(1,activation='sigmoid'))\n"

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 21 (84.00 Byte)
# Trainable params: 21 (84.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=5,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# %%
history = model.fit(X_train_s,y_train,epochs=100,validation_split=0.2, callbacks=callback)
# Out:
# Epoch 1/100
# 875/875 [==============================] - 3s 3ms/step - loss: 0.5460 - accuracy: 0.7291 - val_loss: 0.3434 - val_accuracy: 0.8899
# Epoch 2/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.2745 - accuracy: 0.9404 - val_loss: 0.2262 - val_accuracy: 0.9716
# Epoch 3/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.1996 - accuracy: 0.9844 - val_loss: 0.1783 - val_accuracy: 0.9930
# Epoch 4/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.1628 - accuracy: 0.9977 - val_loss: 0.1502 - val_accuracy: 0.9991
# Epoch 5/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.1397 - accuracy: 0.9999 - val_loss: 0.1316 - val_accuracy: 0.9999
# Epoch 6/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.1236 - accuracy: 0.9998 - val_loss: 0.1181 - val_accuracy: 1.0000
# Epoch 7/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.1119 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 1.0000
# Epoch 8/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.1028 - accuracy: 1.0000 - val_loss: 0.1001 - val_accuracy: 1.0000
# Epoch 9/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0957 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 1.0000
# Epoch 10/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0898 - accuracy: 1.0000 - val_loss: 0.0884 - val_accuracy: 1.0000
# Epoch 11/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0850 - accuracy: 1.0000 - val_loss: 0.0840 - val_accuracy: 1.0000
# Epoch 12/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0808 - accuracy: 1.0000 - val_loss: 0.0801 - val_accuracy: 1.0000
# Epoch 13/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0772 - accuracy: 1.0000 - val_loss: 0.0768 - val_accuracy: 1.0000
# Epoch 14/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0741 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 1.0000
# Epoch 15/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0713 - accuracy: 1.0000 - val_loss: 0.0712 - val_accuracy: 1.0000
# Epoch 16/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0689 - accuracy: 1.0000 - val_loss: 0.0690 - val_accuracy: 1.0000
# Epoch 17/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0667 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 1.0000
# Epoch 18/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0647 - accuracy: 1.0000 - val_loss: 0.0648 - val_accuracy: 1.0000
# Epoch 19/100
# 875/875 [==============================] - 2s 2ms/step - loss: 0.0628 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 1.0000
# Epoch 20/100
# 875/875 [==============================] - 2s 2ms/step - loss: 0.0612 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 1.0000
# Epoch 21/100
# 875/875 [==============================] - 2s 2ms/step - loss: 0.0596 - accuracy: 1.0000 - val_loss: 0.0600 - val_accuracy: 1.0000
# Epoch 22/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0582 - accuracy: 1.0000 - val_loss: 0.0587 - val_accuracy: 1.0000
# Epoch 23/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0568 - accuracy: 1.0000 - val_loss: 0.0573 - val_accuracy: 1.0000
# Epoch 24/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0556 - accuracy: 1.0000 - val_loss: 0.0561 - val_accuracy: 1.0000
# Epoch 25/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0544 - accuracy: 1.0000 - val_loss: 0.0549 - val_accuracy: 1.0000
# Epoch 26/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0533 - accuracy: 1.0000 - val_loss: 0.0539 - val_accuracy: 1.0000
# Epoch 27/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0523 - accuracy: 1.0000 - val_loss: 0.0528 - val_accuracy: 1.0000
# Epoch 28/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 0.0519 - val_accuracy: 1.0000
# Epoch 29/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0504 - accuracy: 1.0000 - val_loss: 0.0510 - val_accuracy: 1.0000
# Epoch 30/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0495 - accuracy: 1.0000 - val_loss: 0.0501 - val_accuracy: 1.0000
# Epoch 31/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0487 - accuracy: 1.0000 - val_loss: 0.0493 - val_accuracy: 1.0000
# Epoch 32/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0479 - accuracy: 1.0000 - val_loss: 0.0485 - val_accuracy: 1.0000
# Epoch 33/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0471 - accuracy: 1.0000 - val_loss: 0.0477 - val_accuracy: 1.0000
# Epoch 34/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0464 - accuracy: 1.0000 - val_loss: 0.0471 - val_accuracy: 1.0000
# Epoch 35/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0457 - accuracy: 1.0000 - val_loss: 0.0464 - val_accuracy: 1.0000
# Epoch 36/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0450 - accuracy: 1.0000 - val_loss: 0.0457 - val_accuracy: 1.0000
# Epoch 37/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0444 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 1.0000
# Epoch 38/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0438 - accuracy: 1.0000 - val_loss: 0.0445 - val_accuracy: 1.0000
# Epoch 39/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.0439 - val_accuracy: 1.0000
# Epoch 40/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0426 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 1.0000
# Epoch 41/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0421 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 1.0000
# Epoch 42/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0416 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 1.0000
# Epoch 43/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0411 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 1.0000
# Epoch 44/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0406 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 1.0000
# Epoch 45/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0401 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 1.0000
# Epoch 46/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0396 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 1.0000
# Epoch 47/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0392 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 1.0000
# Epoch 48/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0388 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 1.0000
# Epoch 49/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0383 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 1.0000
# Epoch 50/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0379 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 1.0000
# Epoch 51/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0375 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 1.0000
# Epoch 52/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0371 - accuracy: 1.0000 - val_loss: 0.0378 - val_accuracy: 1.0000
# Epoch 53/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0368 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 1.0000
# Epoch 54/100
# 875/875 [==============================] - 2s 2ms/step - loss: 0.0364 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 1.0000
# Epoch 55/100
# 875/875 [==============================] - 2s 2ms/step - loss: 0.0360 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 1.0000
# Epoch 56/100
# 875/875 [==============================] - 2s 2ms/step - loss: 0.0357 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 1.0000
# Epoch 57/100
# 875/875 [==============================] - 2s 2ms/step - loss: 0.0353 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 1.0000
# Epoch 58/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.0357 - val_accuracy: 1.0000
# Epoch 59/100
# 875/875 [==============================] - 2s 2ms/step - loss: 0.0347 - accuracy: 1.0000 - val_loss: 0.0354 - val_accuracy: 1.0000
# Epoch 60/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0344 - accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 1.0000
# Epoch 61/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0341 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 1.0000
# Epoch 62/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0338 - accuracy: 1.0000 - val_loss: 0.0345 - val_accuracy: 1.0000
# Epoch 63/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0334 - accuracy: 1.0000 - val_loss: 0.0341 - val_accuracy: 1.0000
# Epoch 64/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 1.0000
# Epoch 65/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0329 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 1.0000
# Epoch 66/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.0333 - val_accuracy: 1.0000
# Epoch 67/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0323 - accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 1.0000
# Epoch 68/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0321 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 1.0000
# Epoch 69/100
# 875/875 [==============================] - 2s 2ms/step - loss: 0.0318 - accuracy: 1.0000 - val_loss: 0.0325 - val_accuracy: 1.0000
# Epoch 70/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0316 - accuracy: 1.0000 - val_loss: 0.0322 - val_accuracy: 1.0000
# Epoch 71/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 1.0000
# Epoch 72/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 1.0000
# Epoch 73/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0308 - accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 1.0000
# Epoch 74/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0306 - accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 1.0000
# Epoch 75/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0304 - accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 1.0000
# Epoch 76/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0301 - accuracy: 1.0000 - val_loss: 0.0308 - val_accuracy: 1.0000
# Epoch 77/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0299 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 78/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0297 - accuracy: 1.0000 - val_loss: 0.0304 - val_accuracy: 1.0000
# Epoch 79/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0295 - accuracy: 1.0000 - val_loss: 0.0302 - val_accuracy: 1.0000
# Epoch 80/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 1.0000
# Epoch 81/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.0297 - val_accuracy: 1.0000
# Epoch 82/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.0295 - val_accuracy: 1.0000
# Epoch 83/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.0293 - val_accuracy: 1.0000
# Epoch 84/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0284 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 85/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 1.0000
# Epoch 86/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 1.0000
# Epoch 87/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0279 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 1.0000
# Epoch 88/100
# 875/875 [==============================] - 2s 2ms/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 0.0284 - val_accuracy: 1.0000
# Epoch 89/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0275 - accuracy: 1.0000 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 90/100
# 875/875 [==============================] - 2s 2ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.0280 - val_accuracy: 1.0000
# Epoch 91/100
# 875/875 [==============================] - 2s 2ms/step - loss: 0.0271 - accuracy: 1.0000 - val_loss: 0.0278 - val_accuracy: 1.0000
# Epoch 92/100
# 875/875 [==============================] - 2s 2ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 1.0000
# Epoch 93/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 1.0000
# Epoch 94/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 1.0000
# Epoch 95/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 96/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.0269 - val_accuracy: 1.0000
# Epoch 97/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0261 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 1.0000
# Epoch 98/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.0266 - val_accuracy: 1.0000
# Epoch 99/100
# 875/875 [==============================] - 2s 2ms/step - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 1.0000
# Epoch 100/100
# 875/875 [==============================] - 2s 3ms/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.0263 - val_accuracy: 1.0000

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend() 

plt.show()

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend() 

plt.show()

# %%
best_accuracy = history.history['val_accuracy'][-1] 
print("Best validation accuracy:", best_accuracy)
# Out:
# Best validation accuracy: 1.0

# %%
y_log = model.predict(X_test_s)
y_log
# Out:
# 469/469 [==============================] - 1s 1ms/step
# array([[6.6863328e-09],
#        [2.4114519e-01],
#        [5.5262626e-06],
#        ...,
#        [1.3242017e-18],
#        [9.9588215e-01],
#        [6.1542160e-10]], dtype=float32)

# %%
y_pred = np.where(y_log>0.5,1,0)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
model.save('Logistic_Regression_model.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
